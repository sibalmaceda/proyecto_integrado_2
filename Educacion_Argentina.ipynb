# %%
# prompt: armar un dataframe de al menos 100 filas con datos random con apellido y nombre, nro_ dni, materias de educacion nivel secundario de la argentina que contenga las siguientes columnas: materia escolar, nota 1er trimestre, nota 2do trimestre, nota 3er trimestre, faltas a clases.

import pandas as pd
import numpy as np
import random

# Define possible values for columns
materias = ['Matemática', 'Lengua y Literatura', 'Historia', 'Geografía', 'Ciencias Naturales', 'Educación Física', 'Inglés', 'Ciudadanía', 'Artes']
apellidos = ['García', 'Rodríguez', 'González', 'Fernández', 'López', 'Martínez', 'Sánchez', 'Pérez', 'Gómez', 'Díaz']
nombres = ['Juan', 'María', 'Pedro', 'Ana', 'Luis', 'Laura', 'Carlos', 'Sofía', 'José', 'Isabel']


# Function to generate random DNI (simplified)
def generate_dni():
    return random.randint(10000000, 99999999)

# Generate data for 100 students
data = []
for _ in range(100):
    apellido = random.choice(apellidos)
    nombre = random.choice(nombres)
    dni = generate_dni()
    materia = random.choice(materias)
    nota1 = random.randint(1, 10)
    nota2 = random.randint(1, 10)
    nota3 = random.randint(1, 10)
    faltas = random.randint(0, 20)
    data.append([apellido, nombre, dni, materia, nota1, nota2, nota3, faltas])

# Create the DataFrame
df =


# Display the DataFrame
df

# %%
# prompt: armar grafico de barras con promedio general de cada materia, ordenados de mayor a menor, agregar las faltas como valor contrastables en dos ejes. agregar las leyendas que ayuden a la interpretacion

import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# ... (previous code) ...

df = pd.DataFrame(data, columns=['Apellido', 'Nombre', 'DNI', 'Materia', 'Nota1', 'Nota2', 'Nota3', 'Faltas'])

# Calculate the average grade for each subject
promedios_por_materia = df.groupby('Materia')[['Nota1', 'Nota2', 'Nota3']].mean().mean(axis=1).sort_values(ascending=False)

# Calculate the total absences for each subject
faltas_por_materia = df.groupby('Materia')['Faltas'].sum()


# Create the bar chart
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot average grades
ax1.bar(promedios_por_materia.index, promedios_por_materia.values, color='skyblue', label='Promedio General')
ax1.set_xlabel('Materia')
ax1.set_ylabel('Promedio', color='skyblue')
ax1.tick_params(axis='y', labelcolor='skyblue')
ax1.set_title('Promedio General por Materia y Faltas')


# Create a second y-axis for absences
ax2 = ax1.twinx()
ax2.plot(faltas_por_materia.index, faltas_por_materia.values, color='red', marker='o', label='Faltas Totales')
ax2.set_ylabel('Faltas', color='red')
ax2.tick_params(axis='y', labelcolor='red')


# Customize the plot
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Add legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right')


plt.show()

# %%
# prompt: podrias otorgarme un codigo para descargar

import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from google.colab import files


# Define possible values for columns
materias = ['Matemática', 'Lengua y Literatura', 'Historia', 'Geografía', 'Ciencias Naturales', 'Educación Física', 'Inglés', 'Ciudadanía', 'Artes']
apellidos = ['García', 'Rodríguez', 'González', 'Fernández', 'López', 'Martínez', 'Sánchez', 'Pérez', 'Gómez', 'Díaz']
nombres = ['Juan', 'María', 'Pedro', 'Ana', 'Luis', 'Laura', 'Carlos', 'Sofía', 'José', 'Isabel']


# Function to generate random DNI (simplified)
def generate_dni():
    return random.randint(10000000, 99999999)

# Generate data for 100 students
data = []
for _ in range(100):
    apellido = random.choice(apellidos)
    nombre = random.choice(nombres)
    dni = generate_dni()
    materia = random.choice(materias)
    nota1 = random.randint(1, 10)
    nota2 = random.randint(1, 10)
    nota3 = random.randint(1, 10)
    faltas = random.randint(0, 20)
    data.append([apellido, nombre, dni, materia, nota1, nota2, nota3, faltas])

# Create the DataFrame
df = pd.DataFrame(data, columns=['Apellido', 'Nombre', 'DNI', 'Materia', 'Nota1', 'Nota2', 'Nota3', 'Faltas'])

# Calculate the average grade for each subject
promedios_por_materia = df.groupby('Materia')[['Nota1', 'Nota2', 'Nota3']].mean().mean(axis=1).sort_values(ascending=False)

# Calculate the total absences for each subject
faltas_por_materia = df.groupby('Materia')['Faltas'].sum()


# Create the bar chart
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot average grades
ax1.bar(promedios_por_materia.index, promedios_por_materia.values, color='skyblue', label='Promedio General')
ax1.set_xlabel('Materia')
ax1.set_ylabel('Promedio', color='skyblue')
ax1.tick_params(axis='y', labelcolor='skyblue')
ax1.set_title('Promedio General por Materia y Faltas')


# Create a second y-axis for absences
ax2 = ax1.twinx()
ax2.plot(faltas_por_materia.index, faltas_por_materia.values, color='red', marker='o', label='Faltas Totales')
ax2.set_ylabel('Faltas', color='red')
ax2.tick_params(axis='y', labelcolor='red')


# Customize the plot
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Add legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right')

# Save the plot to a file
plt.savefig('promedios_faltas.png')

# Download the file
files.download('promedios_faltas.png')

plt.show()
